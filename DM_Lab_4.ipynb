# %%
# Import Required Libraries
import pandas as pd
import numpy as np

# %%
# Load Dataset Using Pandas
df = pd.read_csv("//content/Retail_Dataset_Modified.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
# Display First Five Records
df.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1   BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2     BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
# 3  BX_CHENNAI_061     BrandX_India Trends Chennai  BrandX_India    Mall Store
# 4  BX_CHENNAI_033    BrandX_India Connect Chennai  BrandX_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100g  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1kg  Groceries            Sugar
# 2     Pune     Tier1   Levi's T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    PlayStation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ... Brand_Loyalty Brand_Awareness  Price_Competitiveness  \
# 0     Declining  ...          70.8            75.7               Standard
# 1     Declining  ...          80.5            81.5            Competitive
# 2     Declining  ...          68.5            76.7               Standard
# 3    New Launch  ...          92.4            88.0            Competitive
# 4     Declining  ...          82.9            89.5            Competitive
#
#    Weather_Impact Delivery_Time  Shipping_Cost  Month  Year  Quarter  Season
# 0             Low           6.0             57      1  2022       Q1  Spring
# 1             Low           4.0             99      1  2022       Q1  Spring
# 2          Medium           4.0            101      1  2022       Q1  Spring
# 3          Medium           5.0             79      1  2022       Q1  Spring
# 4             Low           2.0            110      1  2022       Q1  Spring
#
# [5 rows x 47 columns]

# %%
# Display Data Types
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Store_ID                  object
# Store_Name                object
# Brand_Name                object
# Store_Type                object
# City                      object
# City_Tier                 object
# Product_Name              object
# Category                  object
# Sub_Category              object
# Product_Stage             object
# Quantity_Available        object
# Units_Sold                object
# Unit_Price                 int64
# Cost_Price                 int64
# Revenue                   object
# Profit_Margin            float64
# Average_Order_Value        int64
# Inventory_Turnover       float64
# Days_of_Stock              int64
# Customer_Segment          object
# Sales_Channel             object
# Payment_Method            object
# Supplier                  object
# Supplier_Rating           object
# Promotion_Type            object
# Promotion_Impact         float64
# Max_Discount_Offered       int64
# Return_Rate              float64
# Return_Reason             object
# Customer_Satisfaction    float64
# Online_Rating            float64
# Review_Count               int64
# Sales_Rep_Experience       int64
# Sales_Rep_Rating         float64
# Market_Share             float64
# Competition_Level         object
# Competitor_Count           int64
# Brand_Loyalty            float64
# Brand_Awareness          float64
# Price_Competitiveness     object
# Weather_Impact            object
# Delivery_Time            float64
# Shipping_Cost             object
# Month                      int64
# Year                       int64
# Quarter                   object
# Season                    object
# dtype: object

# %%
# Check Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5171 non-null   object
#  1   Store_Name             5171 non-null   object
#  2   Brand_Name             5171 non-null   object
#  3   Store_Type             5171 non-null   object
#  4   City                   5109 non-null   object
#  5   City_Tier              5171 non-null   object
#  6   Product_Name           5098 non-null   object
#  7   Category               5171 non-null   object
#  8   Sub_Category           5171 non-null   object
#  9   Product_Stage          5171 non-null   object
#  10  Quantity_Available     5171 non-null   object
#  11  Units_Sold             5171 non-null   object
#  12  Unit_Price             5171 non-null   int64
#  13  Cost_Price             5171 non-null   int64
#  14  Revenue                5099 non-null   object
#  15  Profit_Margin          5171 non-null   float64
#  16  Average_Order_Value    5171 non-null   int64
#  17  Inventory_Turnover     5171 non-null   float64
#  18  Days_of_Stock          5171 non-null   int64
#  19  Customer_Segment       5171 non-null   object
#  20  Sales_Channel          5171 non-null   object
#  21  Payment_Method         5171 non-null   object
#  22  Supplier               5103 non-null   object
#  23  Supplier_Rating        5171 non-null   object
#  24  Promotion_Type         5171 non-null   object
#  25  Promotion_Impact       5171 non-null   float64
#  26  Max_Discount_Offered   5171 non-null   int64
#  27  Return_Rate            5171 non-null   float64
#  28  Return_Reason          5171 non-null   object
#  29  Customer_Satisfaction  5094 non-null   float64
#  30  Online_Rating          5171 non-null   float64
#  31  Review_Count           5171 non-null   int64
#  32  Sales_Rep_Experience   5171 non-null   int64
#  33  Sales_Rep_Rating       5171 non-null   float64
#  34  Market_Share           5171 non-null   float64
#  35  Competition_Level      5171 non-null   object
#  36  Competitor_Count       5171 non-null   int64
#  37  Brand_Loyalty          5171 non-null   float64
#  38  Brand_Awareness        5171 non-null   float64
#  39  Price_Competitiveness  5171 non-null   object
#  40  Weather_Impact         5171 non-null   object
#  41  Delivery_Time          5111 non-null   float64
#  42  Shipping_Cost          5171 non-null   object
#  43  Month                  5171 non-null   int64
#  44  Year                   5171 non-null   int64
#  45  Quarter                5171 non-null   object
#  46  Season                 5171 non-null   object
# dtypes: float64(11), int64(10), object(26)
# memory usage: 1.9+ MB

# %%
# Convert Quantity_Available to Numeric
df['Quantity_Available'] = pd.to_numeric(
    df['Quantity_Available'],
    errors='coerce')

# %%
print(df['Quantity_Available'].dtypes)
# Out:
# float64

# %%
# Convert Units_Sold to Numeric

df['Units_Sold'] = pd.to_numeric(
    df['Units_Sold'],
    errors='coerce'
)

print(df['Units_Sold'].dtypes)
# Out:
# float64

# %%
# Convert Revenue to Numeric
df['Revenue'] = pd.to_numeric(
    df['Revenue'],
    errors='coerce'
)

print(df['Revenue'].dtypes)
# Out:
# float64

# %%
# Convert Shipping_Cost to Numeric

df['Shipping_Cost'] = pd.to_numeric(
    df['Shipping_Cost'],
    errors='coerce'
)

print(df['Shipping_Cost'].dtypes)
# Out:
# float64

# %%
# Verify Updated Data Types

print(df[['Quantity_Available',
          'Units_Sold',
          'Revenue',
          'Shipping_Cost']].dtypes)
# Out:
# Quantity_Available    float64
# Units_Sold            float64
# Revenue               float64
# Shipping_Cost         float64
# dtype: object

# %%
# Task 2: Handle missing values

# Check Missing Values

print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Store_ID                  0
# Store_Name                0
# Brand_Name                0
# Store_Type                0
# City                     62
# City_Tier                 0
# Product_Name             73
# Category                  0
# Sub_Category              0
# Product_Stage             0
# Quantity_Available        8
# Units_Sold                8
# Unit_Price                0
# Cost_Price                0
# Revenue                  80
# Profit_Margin             0
# Average_Order_Value       0
# Inventory_Turnover        0
# Days_of_Stock             0
# Customer_Segment          0
# Sales_Channel             0
# Payment_Method            0
# Supplier                 68
# Supplier_Rating           0
# Promotion_Type            0
# Promotion_Impact          0
# Max_Discount_Offered      0
# Return_Rate               0
# Return_Reason             0
# Customer_Satisfaction    77
# Online_Rating             0
# Review_Count              0
# Sales_Rep_Experience      0
# Sales_Rep_Rating          0
# Market_Share              0
# Competition_Level         0
# Competitor_Count          0
# Brand_Loyalty             0
# Brand_Awareness           0
# Price_Competitiveness     0
# Weather_Impact            0
# Delivery_Time            60
# Shipping_Cost             8
# Month                     0
# Year                      0
# Quarter                   0
# Season                    0
# dtype: int64

# %%
# Display Columns Having Missing Values

missing_cols = df.isnull().sum()
print(
    missing_cols[missing_cols > 0])
# Out:
# City                     62
# Product_Name             73
# Quantity_Available        8
# Units_Sold                8
# Revenue                  80
# Supplier                 68
# Customer_Satisfaction    77
# Delivery_Time            60
# Shipping_Cost             8
# dtype: int64

# %%
# Fill Missing Values in City Using Mode

df['City'].fillna(
    df['City'].mode()[0],
    inplace=True)
# Out:
# /tmp/ipykernel_856/1523424079.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna(

# %%
#Fill Missing Values in Product Name Using Mode

df['Product_Name'].fillna(
    df['Product_Name'].mode()[0],
    inplace=True)
# Out:
# /tmp/ipykernel_856/1536304599.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Name'].fillna(

# %%
# Fill Missing Values in Quantity Available Using Mean

df['Quantity_Available'].fillna(
    df['Quantity_Available'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/1690444977.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantity_Available'].fillna(

# %%
# Fill Missing Values in Units Sold Using Mean

df['Units_Sold'].fillna(
    df['Units_Sold'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/143135913.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Units_Sold'].fillna(

# %%
# Fill Missing Values in Revenue Using Mean

df['Revenue'].fillna(
    df['Revenue'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/3352724607.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Revenue'].fillna(

# %%
# Fill Missing Values in Supplier Using Mode

df['Supplier'].fillna(
    df['Supplier'].mode()[0],
    inplace=True)
# Out:
# /tmp/ipykernel_856/1700512033.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Supplier'].fillna(

# %%
# Fill Missing Values in Customer Satisfaction Using Mean

df['Customer_Satisfaction'].fillna(
    df['Customer_Satisfaction'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/3829252589.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Customer_Satisfaction'].fillna(

# %%
# Fill Missing Values in Delivery Time Using Mean

df['Delivery_Time'].fillna(
    df['Delivery_Time'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/1708963327.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Delivery_Time'].fillna(

# %%
# Fill Missing Values in Shipping Cost Using Mean

df['Shipping_Cost'].fillna(
    df['Shipping_Cost'].mean(),
    inplace=True)
# Out:
# /tmp/ipykernel_856/1954352356.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Shipping_Cost'].fillna(

# %%
# Verify Missing Values After Cleaning

print(df.isnull().sum())
# Out:
# Store_ID                 0
# Store_Name               0
# Brand_Name               0
# Store_Type               0
# City                     0
# City_Tier                0
# Product_Name             0
# Category                 0
# Sub_Category             0
# Product_Stage            0
# Quantity_Available       0
# Units_Sold               0
# Unit_Price               0
# Cost_Price               0
# Revenue                  0
# Profit_Margin            0
# Average_Order_Value      0
# Inventory_Turnover       0
# Days_of_Stock            0
# Customer_Segment         0
# Sales_Channel            0
# Payment_Method           0
# Supplier                 0
# Supplier_Rating          0
# Promotion_Type           0
# Promotion_Impact         0
# Max_Discount_Offered     0
# Return_Rate              0
# Return_Reason            0
# Customer_Satisfaction    0
# Online_Rating            0
# Review_Count             0
# Sales_Rep_Experience     0
# Sales_Rep_Rating         0
# Market_Share             0
# Competition_Level        0
# Competitor_Count         0
# Brand_Loyalty            0
# Brand_Awareness          0
# Price_Competitiveness    0
# Weather_Impact           0
# Delivery_Time            0
# Shipping_Cost            0
# Month                    0
# Year                     0
# Quarter                  0
# Season                   0
# dtype: int64

# %%
# Display Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5171 non-null   object
#  1   Store_Name             5171 non-null   object
#  2   Brand_Name             5171 non-null   object
#  3   Store_Type             5171 non-null   object
#  4   City                   5171 non-null   object
#  5   City_Tier              5171 non-null   object
#  6   Product_Name           5171 non-null   object
#  7   Category               5171 non-null   object
#  8   Sub_Category           5171 non-null   object
#  9   Product_Stage          5171 non-null   object
#  10  Quantity_Available     5171 non-null   float64
#  11  Units_Sold             5171 non-null   float64
#  12  Unit_Price             5171 non-null   int64
#  13  Cost_Price             5171 non-null   int64
#  14  Revenue                5171 non-null   float64
#  15  Profit_Margin          5171 non-null   float64
#  16  Average_Order_Value    5171 non-null   int64
#  17  Inventory_Turnover     5171 non-null   float64
#  18  Days_of_Stock          5171 non-null   int64
#  19  Customer_Segment       5171 non-null   object
#  20  Sales_Channel          5171 non-null   object
#  21  Payment_Method         5171 non-null   object
#  22  Supplier               5171 non-null   object
#  23  Supplier_Rating        5171 non-null   object
#  24  Promotion_Type         5171 non-null   object
#  25  Promotion_Impact       5171 non-null   float64
#  26  Max_Discount_Offered   5171 non-null   int64
#  27  Return_Rate            5171 non-null   float64
#  28  Return_Reason          5171 non-null   object
#  29  Customer_Satisfaction  5171 non-null   float64
#  30  Online_Rating          5171 non-null   float64
#  31  Review_Count           5171 non-null   int64
#  32  Sales_Rep_Experience   5171 non-null   int64
#  33  Sales_Rep_Rating       5171 non-null   float64
#  34  Market_Share           5171 non-null   float64
#  35  Competition_Level      5171 non-null   object
#  36  Competitor_Count       5171 non-null   int64
#  37  Brand_Loyalty          5171 non-null   float64
#  38  Brand_Awareness        5171 non-null   float64
#  39  Price_Competitiveness  5171 non-null   object
#  40  Weather_Impact         5171 non-null   object
#  41  Delivery_Time          5171 non-null   float64
#  42  Shipping_Cost          5171 non-null   float64
#  43  Month                  5171 non-null   int64
#  44  Year                   5171 non-null   int64
#  45  Quarter                5171 non-null   object
#  46  Season                 5171 non-null   object
# dtypes: float64(15), int64(10), object(22)
# memory usage: 1.9+ MB

# %%
# Task 3: Remove Duplicates

# Count Duplicate Records

duplicates = df.duplicated().sum()

print(
    "Duplicate Records:",
    duplicates)
# Out:
# Duplicate Records: 25

# %%
# Display Duplicate Count

print(df.duplicated().value_counts())
# Out:
# False    5146
# True       25
# Name: count, dtype: int64

# %%
# Remove Duplicate Records

df = df.drop_duplicates()

# %%
# Verify Dataset Shape After Removing Duplicates

print(df.shape)
# Out:
# (5146, 47)

# %%
# Confirm No Duplicate Records Remain

print(
    "Remaining Duplicates:",
    df.duplicated().sum())
# Out:
# Remaining Duplicates: 0

# %%
# Display First Five Records

df.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1   BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2     BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
# 3  BX_CHENNAI_061     BrandX_India Trends Chennai  BrandX_India    Mall Store
# 4  BX_CHENNAI_033    BrandX_India Connect Chennai  BrandX_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100g  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1kg  Groceries            Sugar
# 2     Pune     Tier1   Levi's T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    PlayStation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ...  Brand_Loyalty  Brand_Awareness  Price_Competitiveness  \
# 0     Declining  ...           70.8             75.7               Standard
# 1     Declining  ...           80.5             81.5            Competitive
# 2     Declining  ...           68.5             76.7               Standard
# 3    New Launch  ...           92.4             88.0            Competitive
# 4     Declining  ...           82.9             89.5            Competitive
#
#    Weather_Impact  Delivery_Time  Shipping_Cost  Month  Year  Quarter  Season
# 0             Low            6.0           57.0      1  2022       Q1  Spring
# 1             Low            4.0           99.0      1  2022       Q1  Spring
# 2          Medium            4.0          101.0      1  2022       Q1  Spring
# 3          Medium            5.0           79.0      1  2022       Q1  Spring
# 4             Low            2.0          110.0      1  2022       Q1  Spring
#
# [5 rows x 47 columns]
